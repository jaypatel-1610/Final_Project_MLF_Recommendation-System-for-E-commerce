# %%
summary_stats = df_cleaned[['Score', 'HelpfulnessRatio', 'ReviewLength']].describe()
print(summary_stats)

# 2. Data Visualizations
sns.set(style="whitegrid")

# Histogram of Scores
plt.figure(figsize=(6,4))
sns.countplot(data=df_cleaned, x='Score', palette='viridis')
plt.title("Distribution of Review Scores")
plt.xlabel("Score")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# Histogram of Review Length
plt.figure(figsize=(6,4))
sns.histplot(df_cleaned['ReviewLength'], bins=50, kde=True, color='skyblue')
plt.title("Distribution of Review Length")
plt.xlabel("Review Length (characters)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# Scatter plot: HelpfulnessRatio vs. ReviewLength
plt.figure(figsize=(6,4))
sns.scatterplot(data=df_cleaned.sample(1000, random_state=42),
                x='ReviewLength', y='HelpfulnessRatio', alpha=0.5)
plt.title("Helpfulness Ratio vs. Review Length")
plt.xlabel("Review Length")
plt.ylabel("Helpfulness Ratio")
plt.tight_layout()
plt.show()

# Correlation heatmap
corr_matrix = df_cleaned[['Score', 'HelpfulnessRatio', 'ReviewLength']].corr()
plt.figure(figsize=(5,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
summary_stats = df_cleaned[['Score', 'HelpfulnessRatio', 'ReviewLength']].describe()
print(summary_stats)

# 2. Data Visualizations
sns.set(style="whitegrid")

# Histogram of Scores
plt.figure(figsize=(6,4))
sns.countplot(data=df_cleaned, x='Score', palette='viridis')
plt.title("Distribution of Review Scores")
plt.xlabel("Score")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# Histogram of Review Length
plt.figure(figsize=(6,4))
sns.histplot(df_cleaned['ReviewLength'], bins=50, kde=True, color='skyblue')
plt.title("Distribution of Review Length")
plt.xlabel("Review Length (characters)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# Scatter plot: HelpfulnessRatio vs. ReviewLength
plt.figure(figsize=(6,4))
sns.scatterplot(data=df_cleaned.sample(1000, random_state=42),
                x='ReviewLength', y='HelpfulnessRatio', alpha=0.5)
plt.title("Helpfulness Ratio vs. Review Length")
plt.xlabel("Review Length")
plt.ylabel("Helpfulness Ratio")
plt.tight_layout()
plt.show()

# Correlation heatmap
corr_matrix = df_cleaned[['Score', 'HelpfulnessRatio', 'ReviewLength']].corr()
plt.figure(figsize=(5,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
df = df.sample(n=5000, random_state=42) 
df['Sentiment'] = df['Score'].apply(score_to_sentiment)

X = df['Text']
y = df['Sentiment']

vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
X_tfidf = vectorizer.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

lr = LogisticRegression(max_iter=200)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

nb = MultinomialNB()
nb.fit(X_train, y_train)
y_pred_nb = nb.predict(X_test)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print("Logistic Regression:\n", classification_report(y_test, y_pred_lr))
print("Naive Bayes:\n", classification_report(y_test, y_pred_nb))
print("Random Forest:\n", classification_report(y_test, y_pred_rf))

print("✅ All models trained and evaluated!")
